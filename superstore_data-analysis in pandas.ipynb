# %%
import pandas as pd
a = pd.read_csv("D:\projects internship\internspark\Project 2\superstore_final_dataset (1).csv")

# %%
ans = pd.read_excel("D:\projects internship\internspark\Project 2\proccessed data 2.xlsx")

# %%
ans.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
ans.groupby('State')['Sales'].sum().nlargest(5)
# Out:
# State
# California      446306.4635
# New York        306361.1470
# Texas           168572.5322
# Washington      135206.8500
# Pennsylvania    116276.6500
# Name: Sales, dtype: float64

# %%
ans.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
ans.groupby('Sub_Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Sub_Category
# Phones         327782.4480
# Chairs         322822.7310
# Storage        219343.3920
# Tables         202810.6280
# Binders        200028.7850
# Machines       189238.6310
# Accessories    164186.7000
# Copiers        146248.0940
# Bookcases      113813.1987
# Appliances     104618.4030
# Furnishings     89212.0180
# Paper           76828.3040
# Supplies        46420.3080
# Art             26705.4100
# Envelopes       16128.0460
# Labels          12347.7260
# Fasteners        3001.9600
# Name: Sales, dtype: float64

# %%
ans.groupby('Product_Name')['Sales'].sum().nlargest(10)
# Out:
# Product_Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24 Color                       18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
ans.groupby('Region')['Sales'].mean().sort_values(ascending=False)
# Out:
# Region
# South      243.524067
# East       240.401697
# West       226.184613
# Central    216.357889
# Name: Sales, dtype: float64

# %%
ans.groupby(['State','Category'])['Sales'].sum().reset_index().sort_values(['State','Sales'], ascending=[True,False])
# Out:
#              State         Category      Sales
# 2          Alabama       Technology   8969.080
# 0          Alabama        Furniture   6332.480
# 1          Alabama  Office Supplies   4209.080
# 3          Arizona        Furniture  13525.291
# 5          Arizona       Technology  11750.885
# ..             ...              ...        ...
# 137  West Virginia  Office Supplies    536.480
# 138      Wisconsin        Furniture  16757.850
# 140      Wisconsin       Technology   8376.360
# 139      Wisconsin  Office Supplies   6039.220
# 141        Wyoming        Furniture   1603.136
#
# [142 rows x 3 columns]

# %%
print(ans.info)
# Out:
# <bound method DataFrame.info of       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9795    9796  CA-2017-125920 2017-05-21 2017-05-28  Standard Class
# 9796    9797  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9797    9798  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9798    9799  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
# 9799    9800  CA-2016-128608 2016-01-12 2016-01-17  Standard Class
#
#      Customer_ID     Customer_Name    Segment        Country             City  \
# ...

# %%
print(ans.head(10))
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 5       6  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 6       7  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 7       8  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 8       9  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
# 9      10  CA-2015-115812 2015-06-09 2015-06-14  Standard Class    BH-11710
#
#      Customer_Name    Segment        Country             City       State  \
# ...
